# %%
import torch
import torch.nn as nn
from deepart.models import DeepARTWrapper

base = nn.Sequential(
    nn.Linear(784, 256, bias=False),
    nn.ReLU(),
    nn.Linear(256, 10, bias=False),
)

model = DeepARTWrapper(
    base,
    # learning_rule="oja",
    learning_rule="fuzzyart",
    eta=0.01,
    beta_rule="wta",
    apply_complement_coding=True,
)

x = torch.rand(32, 784)
target = torch.randint(0, 10, (32,))  # optional
y_hat = model.learn_step(x, target=target)  # forward + local weight updates

# %%
y_hat
# Out:
# tensor([[ 0.1480,  0.0348, -0.0315,  0.1123,  0.2461,  0.0170,  0.0215, -0.3122,
#           0.1484,  0.0970],
#         [ 0.0977,  0.0874,  0.0606,  0.1260,  0.1591,  0.1027, -0.0943, -0.3962,
#           0.0082, -0.0839],
#         [ 0.0959,  0.1483, -0.1137,  0.1156,  0.1223,  0.1149, -0.0753, -0.4278,
#          -0.0628, -0.0953],
#         [ 0.0351, -0.0054, -0.0632, -0.0026,  0.1693,  0.1354, -0.0526, -0.3043,
#           0.0702,  0.0810],
#         [-0.0083,  0.1049, -0.0813,  0.1000,  0.1106,  0.1321,  0.0232, -0.3153,
#           0.0743,  0.0031],
#         [ 0.0425, -0.0063,  0.0549,  0.1061,  0.1520,  0.1626, -0.1548, -0.3767,
#           0.0357, -0.1032],
#         [-0.0081,  0.1955, -0.1150,  0.0223,  0.1530,  0.0860, -0.0013, -0.5328,
#           0.0641, -0.0986],
#         [ 0.0425,  0.0591, -0.0719,  0.1808,  0.2098,  0.2828,  0.0442, -0.4668,
#           0.0771,  0.0026],
#         [ 0.1829,  0.1095,  0.0562,  0.0873,  0.1244,  0.0216, -0.0533, -0.4321,
#          -0.0030, -0.0094],
#         [ 0.0021,  0.0607, -0.1719,  0.0548,  0.0640,  0.1488, -0.1390, -0.4932,
#           0.1398, -0.0282],
#         [ 0.0584,  0.0776, -0.1267, -0.0583,  0.1676,  0.1695, -0.1084, -0.3697,
#           0.0601,  0.0204],
#         [ 0.1885,  0.0267, -0.1032,  0.1593,  0.2282,  0.0523, -0.0302, -0.3388,
#           0.0076,  0.1218],
#         [ 0.1579,  0.0207, -0.1164,  0.0608,  0.1284,  0.0487,  0.0337, -0.4250,
#          -0.0177,  0.0040],
#         [-0.0063,  0.0144, -0.1597, -0.0006,  0.3101, -0.0028, -0.0687, -0.3258,
#           0.0702,  0.0786],
#         [ 0.0239,  0.1463,  0.0429,  0.0009,  0.0901,  0.1154,  0.0785, -0.2944,
#           0.1089,  0.0104],
#         [ 0.0630,  0.2522, -0.1411,  0.0739,  0.2281,  0.2249, -0.1005, -0.4334,
#           0.1218, -0.1497],
#         [-0.0053,  0.1583, -0.0834,  0.0538,  0.0911,  0.0626, -0.0235, -0.3522,
#           0.1203, -0.1548],
#         [ 0.0086,  0.0840,  0.0014,  0.0994,  0.1475,  0.1355, -0.0422, -0.4047,
#           0.1442,  0.0242],
#         [ 0.1111,  0.0384,  0.0493, -0.0582,  0.1376,  0.1124, -0.0598, -0.3344,
#           0.0573, -0.0075],
#         [ 0.1196,  0.0729, -0.1107,  0.1406,  0.1341,  0.1238, -0.1701, -0.4162,
#           0.0196,  0.1206],
#         [ 0.0769,  0.0976,  0.0457,  0.0458,  0.2568,  0.0878, -0.0828, -0.4037,
#          -0.0285,  0.0123],
#         [ 0.2161,  0.1009, -0.1128,  0.1342,  0.1869,  0.1094, -0.0291, -0.3778,
#           0.0943, -0.1129],
#         [ 0.0719,  0.0740, -0.1592,  0.0706,  0.1214,  0.0678, -0.1134, -0.3277,
#           0.0943,  0.0899],
#         [ 0.0358,  0.0652,  0.0251, -0.0574,  0.1875, -0.0007, -0.1068, -0.3500,
#           0.1322, -0.0294],
#         [ 0.0730,  0.0299, -0.0484,  0.0093,  0.1447,  0.0901, -0.0532, -0.4187,
#           0.0153, -0.0919],
#         [ 0.0867,  0.1472, -0.0674,  0.0052,  0.2100,  0.0678,  0.0367, -0.4037,
#           0.0291, -0.0487],
#         [-0.0020,  0.1579, -0.0299,  0.0185,  0.1690,  0.1081, -0.1163, -0.2805,
#           0.0657, -0.1129],
#         [ 0.0622,  0.1627, -0.0550,  0.0301,  0.1520,  0.1934, -0.1677, -0.3408,
#           0.0832, -0.0832],
#         [ 0.0355,  0.0792, -0.1874,  0.0801,  0.1052,  0.0743, -0.1017, -0.3976,
#           0.0420, -0.0317],
#         [ 0.0341,  0.0636, -0.2032, -0.0057,  0.0544, -0.0205, -0.0716, -0.3688,
#           0.0674,  0.0974],
#         [ 0.0052,  0.2247, -0.0537,  0.0832,  0.0877,  0.1670,  0.0153, -0.3768,
#           0.1221, -0.0286],
#         [ 0.0117,  0.1502, -0.0735,  0.0707,  0.1944,  0.1890,  0.0258, -0.4277,
#           0.0258, -0.0540]])
